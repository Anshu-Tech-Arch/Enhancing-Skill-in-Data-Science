# %%
import numpy as np

# %%
a=np.array([1,2,3])
b=np.array([[1,2,3], [4,5,6]])
c=np.array([[[1,2,3], [4,5,6]]])
d=np.array(1)

# %%
a, b, c, d
# Out:
# (array([1, 2, 3]),
#  array([[1, 2, 3],
#         [4, 5, 6]]),
#  array([[[1, 2, 3],
#          [4, 5, 6]]]),
#  array(1))

# %%
print(a.ndim)
print(b.ndim)
print(c.ndim)
print(d.ndim)
# Out:
# 1
# 2
# 3
# 0

# %%
a=np.array([1, "2", 3])
a
# Out:
# array(['1', '2', '3'], dtype='<U21')

# %%
b=np.array([])
